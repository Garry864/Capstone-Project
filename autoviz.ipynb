# %%
import os
import pandas as pd
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
df =  pd.read_csv('dataset/CAR_DETAILS_clean.csv')
df.shape
# Out:
# (3550, 8)

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# Initialize AutoViz class
AV = AutoViz_Class()

# Generate AutoViz report and save plots in the specified directory
df_AV = AV.AutoViz('dataset/CAR_DETAILS_clean.csv', chart_format='svg')
# Out:
# Shape of your Data Set loaded: (3550, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     8 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 7 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_04122_row0_col0, #T_04122_row0_col3, #T_04122_row0_col4, #T_04122_row0_col5, #T_04122_row1_col0, #T_04122_row1_col3, #T_04122_row1_col4, #T_04122_row1_col5, #T_04122_row2_col0, #T_04122_row2_col3, #T_04122_row2_col4, #T_04122_row2_col5, #T_04122_row3_col0, #T_04122_row3_col3, #T_04122_row3_col4, #T_04122_row3_col5, #T_04122_row4_col0, #T_04122_row4_col3, #T_04122_row4_col4, #T_04122_row4_col5, #T_04122_row5_col0, #T_04122_row5_col3, #T_04122_row5_col4, #T_04122_row5_col5, #T_04122_row6_col0, #T_04122_row6_col3, #T_04122_row6_col4, #T_04122_row6_col5, #T_04122_row7_col0, #T_04122_row7_col3, #T_04122_row7_col4, #T_04122_row7_col5 {
#   font-family: Segoe UI;
# }
# #T_04122_row0_col1, #T_04122_row0_col2, #T_04122_row1_col1, #T_04122_row2_col1, #T_04122_row3_col1, #T_04122_row3_col2, #T_04122_row4_col1, #T_04122_row4_col2, #T_04122_row5_col1, #T_04122_row5_col2, #T_04122_row6_col1, #T_04122_row6_col2, #T_04122_row7_col1, #T_04122_row7_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_04122_row1_col2 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_04122_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_04122">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04122_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_04122_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_04122_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_04122_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_04122_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_04122_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04122_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_04122_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_04122_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_04122_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_04122_row0_col3" class="data row0 col3" >2001.000000</td>
#       <td id="T_04122_row0_col4" class="data row0 col4" >2020.000000</td>
#       <td id="T_04122_row0_col5" class="data row0 col5" >Possible date-time colum: transform before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row1" class="row_heading level0 row1" >selling_price</th>
#       <td id="T_04122_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_04122_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_04122_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_04122_row1_col3" class="data row1 col3" >20000.000000</td>
#       <td id="T_04122_row1_col4" class="data row1 col4" >1200000.000000</td>
#       <td id="T_04122_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row2" class="row_heading level0 row2" >km_driven</th>
#       <td id="T_04122_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_04122_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_04122_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_04122_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_04122_row2_col4" class="data row2 col4" >171000.000000</td>
#       <td id="T_04122_row2_col5" class="data row2 col5" >Column has 118 outliers greater than upper bound (169500.00) or lower than lower bound(-42500.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row3" class="row_heading level0 row3" >fuel</th>
#       <td id="T_04122_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_04122_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_04122_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_04122_row3_col3" class="data row3 col3" ></td>
#       <td id="T_04122_row3_col4" class="data row3 col4" ></td>
#       <td id="T_04122_row3_col5" class="data row3 col5" >2 rare categories: ['LPG', 'Electric']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row4" class="row_heading level0 row4" >seller_type</th>
#       <td id="T_04122_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_04122_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_04122_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_04122_row4_col3" class="data row4 col3" ></td>
#       <td id="T_04122_row4_col4" class="data row4 col4" ></td>
#       <td id="T_04122_row4_col5" class="data row4 col5" >1 rare categories: ['Trustmark Dealer']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row5" class="row_heading level0 row5" >transmission</th>
#       <td id="T_04122_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_04122_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_04122_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_04122_row5_col3" class="data row5 col3" ></td>
#       <td id="T_04122_row5_col4" class="data row5 col4" ></td>
#       <td id="T_04122_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row6" class="row_heading level0 row6" >owner</th>
#       <td id="T_04122_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_04122_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_04122_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_04122_row6_col3" class="data row6 col3" ></td>
#       <td id="T_04122_row6_col4" class="data row6 col4" ></td>
#       <td id="T_04122_row6_col5" class="data row6 col5" >1 rare categories: ['Test Drive Car']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_04122_level0_row7" class="row_heading level0 row7" >Brand</th>
#       <td id="T_04122_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_04122_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_04122_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_04122_row7_col3" class="data row7 col3" ></td>
#       <td id="T_04122_row7_col4" class="data row7 col4" ></td>
#       <td id="T_04122_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 5 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
